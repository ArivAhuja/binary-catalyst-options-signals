# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
biotech_catalysts_df = pd.read_pickle('biotech_catalysts/biotech_catalysts_data.pkl')
biotech_catalysts_df
# Out:
#                           ticker     event_type  result  \
# date
# 2024-06-24 12:00:00+00:00   ALNY  Clinical Data       1
# 2024-11-22 22:00:00+00:00   BBIO            FDA       1
# 2025-02-18 13:00:00+00:00   SLDB  Clinical Data       1
# 2025-02-24 13:00:00+00:00   PEPG  Clinical Data       1
# 2025-03-28 12:00:00+00:00   MIST            FDA      -1
# 2025-04-03 12:00:00+00:00   ALDX            FDA      -1
# 2025-04-17 12:00:00+00:00   QURE            FDA       1
# 2025-05-24 12:00:00+00:00   LQDA            FDA       0
# 2025-05-26 12:00:00+00:00    MRK            FDA       0
# 2025-05-31 12:00:00+00:00   MRNA            FDA       0
# 2025-06-23 12:00:00+00:00   NUVB            FDA       0
#
# ...

# %%
qure = pd.read_pickle('option_data/qure_2025-04-17 12:00:00_call_1.pkl')
qure
# Out:
#                           QURE CALL $2 2025-04-17 16:00:00-04:00            \
#                                                             open high  low
# timestamp
# 2025-01-09 05:00:00+00:00                                    7.3  7.3  7.3
# 2025-01-23 05:00:00+00:00                                    7.3  7.3  7.3
# 2025-02-06 05:00:00+00:00                                    7.3  7.3  7.3
# 2025-02-20 05:00:00+00:00                                    7.3  7.3  7.3
# 2025-03-06 05:00:00+00:00                                    7.3  7.3  7.3
# 2025-03-20 04:00:00+00:00                                    7.3  7.3  7.3
# 2025-04-03 04:00:00+00:00                                    7.3  7.3  7.3
#
#                                                                      \
#                           close volume vwap transactions stock_vwap
# timestamp
# 2025-01-09 05:00:00+00:00   7.3    0.0  7.3          0.0    14.1431
# ...

# %%
pepg = pd.read_pickle('option_data/alny_2024-06-24 12:00:00_put_1.pkl')
pepg
# Out:
#                           ALNY PUT $220 2024-08-16 16:00:00-04:00         \
#                                                              open   high
# timestamp
# 2024-03-18 04:00:00+00:00                                   71.62  73.35
# 2024-04-01 04:00:00+00:00                                   71.62  73.35
# 2024-04-15 04:00:00+00:00                                   71.62  73.35
# 2024-04-29 04:00:00+00:00                                   71.62  73.35
# 2024-05-13 04:00:00+00:00                                   71.62  73.35
# 2024-05-27 04:00:00+00:00                                   71.62  73.35
# 2024-06-10 04:00:00+00:00                                   71.62  73.35
#
#                                                                       \
#                              low  close volume     vwap transactions
# timestamp
# 2024-03-18 04:00:00+00:00  71.62  73.35    0.0  72.2342          0.0
# 2024-04-01 04:00:00+00:00  71.62  73.35    0.0  72.2342          0.0
# ...

# %%
mrk = pd.read_pickle('option_data/mrk_2025-05-26 12:00:00_call_0.pkl')
mrk
# Out:
#                           MRK CALL $40 2025-10-17 16:00:00-04:00         \
#                                                             open   high
# timestamp
# 2025-02-17 05:00:00+00:00                                  39.50  39.50
# 2025-03-03 05:00:00+00:00                                  39.50  39.50
# 2025-03-17 04:00:00+00:00                                  39.50  39.50
# 2025-03-31 04:00:00+00:00                                  39.50  39.50
# 2025-04-14 04:00:00+00:00                                  39.50  39.50
# 2025-04-28 04:00:00+00:00                                  41.05  41.05
# 2025-05-12 04:00:00+00:00                                  41.05  41.05
#
#                                                                                \
#                              low  close volume   vwap transactions stock_vwap
# timestamp
# 2025-02-17 05:00:00+00:00  39.00  39.00    0.0  39.25          0.0    88.2485
# ...

# %%
iv_matrix = pd.read_pickle('iv_matrix/alny_2024-06-24 12:00:00_call_1_ivmatrix.pkl')
iv_matrix
# Out:
#                           ALNY CALL $75 2025-12-19 16:00:00-05:00  \
# timestamp
# 2024-03-18 04:00:00+00:00                                     NaN
# 2024-04-01 04:00:00+00:00                                     NaN
# 2024-04-15 04:00:00+00:00                                     NaN
# 2024-04-29 04:00:00+00:00                                     NaN
# 2024-05-13 04:00:00+00:00                                     NaN
# 2024-05-27 04:00:00+00:00                                     NaN
# 2024-06-10 04:00:00+00:00                                0.530276
#
#                           ALNY CALL $90 2025-12-19 16:00:00-05:00  \
# timestamp
# 2024-03-18 04:00:00+00:00                                     NaN
# 2024-04-01 04:00:00+00:00                                     NaN
# 2024-04-15 04:00:00+00:00                                     NaN
# 2024-04-29 04:00:00+00:00                                     NaN
# 2024-05-13 04:00:00+00:00                                0.530293
# ...
