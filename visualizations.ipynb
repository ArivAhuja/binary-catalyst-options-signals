# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
biotech_catalysts_df = pd.read_pickle('biotech_catalysts_data/biotech_catalysts.pkl')
biotech_catalysts_df
# Out:
#                     ticker      event_type  result  \
# date
# 2025-02-18 08:00:00   SLDB  Phase 1/2 Data       1
# 2025-02-24 08:00:00   PEPG    Phase 1 Data       1
#
#                                                                                                                                                                                                                                                      details
# date
# 2025-02-18 08:00:00    Solid Biosciences reported positive initial data from the Phase 1/2 INSPIRE DUCHENNE trial, showing 110% average microdystrophin expression in the first three participants and significant improvements in muscle health biomarkers.
# 2025-02-24 08:00:00  PepGen announced positive initial results from FREEDOM-DM1 trial in patients with Myotonic Dystrophy Type 1, showing significant mean splicing correction of 29.1% following a single dose at 10 mg/kg with a favorable safety profile.

# %%
sldb = pd.read_pickle('option_data/sldb_put_option_data.pkl')
sldb
# Out:
#     (O:SLDB250221P00002500, 2.5, 2025-02-21, put, SLDB)                    \
#                                                    open  high   low close
# -98                                                0.25  0.25  0.25  0.25
# -84                                                0.25  0.25  0.25  0.25
# -70                                                0.25  0.25  0.25  0.25
# -56                                                0.30  0.30  0.30  0.30
# -42                                                0.55  0.73  0.30  0.70
# -28                                                0.55  0.76  0.40  0.45
# -14                                                0.45  0.62  0.05  0.08
#
#                                   \
#      volume    vwap transactions
# -98     0.0  0.2500          0.0
# -84     0.0  0.2500          0.0
# -70     2.0  0.2500          2.0
# -56     2.0  0.3000          2.0
# -42  4382.0  0.5307         74.0
# -28  3454.0  0.6429        576.0
# ...

# %%
pepg = pd.read_pickle('option_data/pepg_call_option_data.pkl')
pepg
# Out:
#     (O:PEPG250321C00001000, 1, 2025-03-21, call, PEPG)                         \
#                                                   open high  low close volume
# -98                                                0.6  0.6  0.6   0.6    0.0
# -84                                                0.6  0.6  0.6   0.6    0.0
# -70                                                0.6  0.6  0.6   0.6    0.0
# -56                                                0.6  0.6  0.6   0.6    0.0
# -42                                                0.6  0.6  0.6   0.6    0.0
# -28                                                0.6  0.6  0.6   0.6    0.0
# -14                                                0.6  0.6  0.6   0.6    1.0
#
#                       (O:PEPG250321C00002000, 2, 2025-03-21, call, PEPG)  \
#     vwap transactions                                               open
# -98  0.6          0.0                                               0.25
# ...
