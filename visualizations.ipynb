# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
biotech_catalysts_df = pd.read_pickle('biotech_catalysts/biotech_catalysts_data.pkl')
biotech_catalysts_df
# Out:
#                     ticker    event_type  result  \
# date
# 2024-11-22 16:00:00   BBIO  FDA Approval       1
# 2025-03-20 10:15:00   ALNY  FDA Approval       1
#
#                                                                                                                                                                                                                      details
# date
# 2024-11-22 16:00:00                             FDA approved Attruby (acoramidis), a near-complete TTR stabilizer, to reduce cardiovascular death and cardiovascular-related hospitalization in adult patients with ATTR-CM.
# 2025-03-20 10:15:00  FDA approved AMVUTTRA (vutrisiran) as the first RNAi therapeutic to reduce cardiovascular death, hospitalizations, and urgent heart failure visits in adults with ATTR amyloidosis with cardiomyopathy.

# %%
alny = pd.read_pickle('option_data/alny_call_option_data.pkl')
alny
# Out:
#                           ALNY CALL $100 2025-12-19 16:00:00-05:00          \
#                                                               open    high
# timestamp
# 2024-12-12 05:00:00+00:00                                   144.76  144.76
# 2024-12-26 05:00:00+00:00                                   144.76  144.76
# 2025-01-09 05:00:00+00:00                                   144.76  144.76
# 2025-01-23 05:00:00+00:00                                   144.76  144.76
# 2025-02-06 05:00:00+00:00                                   144.76  144.76
# 2025-02-20 05:00:00+00:00                                   144.76  144.76
# 2025-03-06 05:00:00+00:00                                   144.76  144.76
#
#                                                                        \
#                               low   close volume    vwap transactions
# timestamp
# 2024-12-12 05:00:00+00:00  144.76  144.76   10.0  144.76          2.0
# ...

# %%
pepg = pd.read_pickle('option_data/pepg_call_option_data.pkl')
pepg
# Out:
#                     PEPG CALL $1 2025-03-21 16:00:00-04:00                  \
#                                                       open high  low close
# timestamp
# 2024-11-18 05:00:00                                    0.6  0.6  0.6   0.6
# 2024-12-02 05:00:00                                    0.6  0.6  0.6   0.6
# 2024-12-16 05:00:00                                    0.6  0.6  0.6   0.6
# 2024-12-30 05:00:00                                    0.6  0.6  0.6   0.6
# 2025-01-13 05:00:00                                    0.6  0.6  0.6   0.6
# 2025-01-27 05:00:00                                    0.6  0.6  0.6   0.6
# 2025-02-10 05:00:00                                    0.6  0.6  0.6   0.6
#
#                                                          \
#                     volume vwap transactions stock_vwap
# timestamp
# 2024-11-18 05:00:00    0.0  0.6          0.0     4.7122
# 2024-12-02 05:00:00    0.0  0.6          0.0     5.3944
# ...

# %%
bbio = pd.read_pickle('option_analysis/bbio_put_option_data_iv_matrix.pkl')
bbio
# Out:
#                           BBIO PUT $40 2025-01-17 16:00:00-05:00  \
# timestamp
# 2024-08-16 04:00:00+00:00                                0.66013
# 2024-08-30 04:00:00+00:00                                    NaN
# 2024-09-13 04:00:00+00:00                                    NaN
# 2024-09-27 04:00:00+00:00                                    NaN
# 2024-10-11 04:00:00+00:00                                    NaN
# 2024-10-25 04:00:00+00:00                               0.528551
# 2024-11-08 05:00:00+00:00                               1.232925
#
#                           BBIO PUT $35 2024-12-20 16:00:00-05:00  \
# timestamp
# 2024-08-16 04:00:00+00:00                                    NaN
# 2024-08-30 04:00:00+00:00                                    NaN
# 2024-09-13 04:00:00+00:00                                    NaN
# 2024-09-27 04:00:00+00:00                               0.611294
# 2024-10-11 04:00:00+00:00                                    NaN
# ...

# %%
alny = pd.read_pickle('option_analysis/alny_put_option_data_iv_matrix.pkl')
alny
# Out:
#                           ALNY PUT $310 2025-09-19 16:00:00-04:00  \
# timestamp
# 2024-12-12 05:00:00+00:00                                     NaN
# 2024-12-26 05:00:00+00:00                                     NaN
# 2025-01-09 05:00:00+00:00                                     NaN
# 2025-01-23 05:00:00+00:00                                     NaN
# 2025-02-06 05:00:00+00:00                                0.406654
# 2025-02-20 05:00:00+00:00                                     NaN
# 2025-03-06 05:00:00+00:00                                     NaN
#
#                           ALNY PUT $310 2027-01-15 16:00:00-05:00  \
# timestamp
# 2024-12-12 05:00:00+00:00                                     NaN
# 2024-12-26 05:00:00+00:00                                     NaN
# 2025-01-09 05:00:00+00:00                                     NaN
# 2025-01-23 05:00:00+00:00                                0.383939
# 2025-02-06 05:00:00+00:00                                     NaN
# ...

# %%
iv_vector = np.load('option_analysis/alny_call_iv_data.npy')
iv_vector
# Out:
# array([0.37113986, 0.3820353 , 0.35205312, 0.36063775, 0.40809456,
#        0.40520582, 0.45998098])
